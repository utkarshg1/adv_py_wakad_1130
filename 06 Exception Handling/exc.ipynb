# %% [markdown]
# # Exception Handling
# When you perform some incorrect operations you get an exception in python

# %%
a = 5
print(a / 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 a = 5
# ----> 2 print(a / 0)
#
# ZeroDivisionError: division by zero

# %%
b = "Example"
print(b / 12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 b = "Example"
# ----> 2 print(b / 12)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
a = "28"
type(a)
# Out:
# str

# %%
b = int(a)
print(b, type(b))
# Out:
# 28 <class 'int'>

# %%
c = "abc"
d = int(c)
print(3 + 5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 c = "abc"
# ----> 2 d = int(c)
#       3 print(3 + 5)
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# # Division function without exception handling

# %%
def division(a: int | float, b: int | float) -> float:
    c = a / b
    return c

# %%
d1 = division(a=23, b=7)
print(d1)
print("Completed")
# Out:
# 3.2857142857142856
# Completed

# %%
d2 = division(a=25, b=0)
print(d2)
print("Completed")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 d2 = division(a=25, b=0)
#       2 print(d2)
#       3 print("Completed")
#
# Cell In[8], line 2, in division(a, b)
#       1 def division(a: int | float, b: int | float) -> float:
# ----> 2     c = a / b
#       3     return c
#
# ZeroDivisionError: division by zero

# %%
d2 = division(a="abc", b=3)
print(d2)
print("Completed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 d2 = division(a="abc", b=3)
#       2 print(d2)
#       3 print("Completed")
#
# Cell In[8], line 2, in division(a, b)
#       1 def division(a: int | float, b: int | float) -> float:
# ----> 2     c = a / b
#       3     return c
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# # Generic Exception handling

# %%
help(Exception)
# Out:
# Help on class Exception in module builtins:
#
# class Exception(BaseException)
#  |  Common base class for all non-exit exceptions.
#  |
#  |  Method resolution order:
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Built-in subclasses:
#  |      ArithmeticError
#  |      AssertionError
#  |      AttributeError
#  |      BufferError
#  |      ... and 16 other subclasses
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs)
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __reduce__(self, /)
#  |      Helper for pickle.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, object, /)
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  add_note(self, object, /)
#  |      Exception.add_note(note) --
#  |      add a note to the exception
#  |
#  |  with_traceback(self, object, /)
#  |      Exception.with_traceback(tb) --
#  |      set self.__traceback__ to tb and return self.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BaseException:
#  |
#  |  __cause__
#  |      exception cause
#  |
#  |  __context__
#  |      exception context
#  |
#  |  __dict__
#  |
#  |  __suppress_context__
#  |
#  |  __traceback__
#  |
#  |  args

# %%
def division2(num: int | float, den: int | float) -> float | None:
    try:
        div = num / den
        return div
    except Exception as e:
        print(f"Exception occured : {e}")

# %%
a = division2(num=100, den=26)
print(a)
print("Completed")
# Out:
# 3.8461538461538463
# Completed

# %%
b = division2(num=25, den=0)
print(b)
print("Completed")
# Out:
# Exception occured : division by zero
# None
# Completed

# %%
c = division2(num="abc", den=4)
print(c)
print("Completed")
# Out:
# Exception occured : unsupported operand type(s) for /: 'str' and 'int'
# None
# Completed

# %%
d = division2(num="a", den="b")
print(d)
print("Completed")
# Out:
# Exception occured : unsupported operand type(s) for /: 'str' and 'str'
# None
# Completed

# %% [markdown]
# # Use differnent exceptions for each errors

# %%
def division3(num: int | float, den: int | float) -> float | None:
    try:
        div = num / den
        return div
    except ZeroDivisionError:
        print("Denomator of division cannot be Zero")
    except TypeError:
        print("Provide number input for numerator and denominator")
    except Exception as e:
        print(f"Unexpcted exception occured : {e}")

# %%
a = division3(num=23, den=6)
print(a)
print("Complete")
# Out:
# 3.8333333333333335
# Complete

# %%
b = division3(num=35, den=0)
print(b)
print("Complete")
# Out:
# Denomator of division cannot be Zero
# None
# Complete

# %%
c = division3(num=3, den="b")
print(c)
print("Complete")
# Out:
# Provide number input for numerator and denominator
# None
# Complete

# %% [markdown]
# # You can also raise an error in python whenever required

# %%
def age_validator(age: int) -> int | None:
    if age <= 0 or age >= 100:
        raise ValueError("Age should be between 1 and 100")
    return age

# %%
a1 = age_validator(25)
print(a1)
# Out:
# 25

# %%
a2 = age_validator(-23)
print(a2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 a2 = age_validator(-23)
#       2 print(a2)
#
# Cell In[37], line 3, in age_validator(age)
#       1 def age_validator(age: int) -> int | None:
#       2     if age <= 0 or age >= 100:
# ----> 3         raise ValueError("Age should be between 1 and 100")
#       4     return age
#
# ValueError: Age should be between 1 and 100

# %%
a3 = age_validator(200)
print(a3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 a3 = age_validator(200)
#       2 print(a3)
#
# Cell In[37], line 3, in age_validator(age)
#       1 def age_validator(age: int) -> int | None:
#       2     if age <= 0 or age >= 100:
# ----> 3         raise ValueError("Age should be between 1 and 100")
#       4     return age
#
# ValueError: Age should be between 1 and 100

# %%
a3 = age_validator("abc")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 a3 = age_validator("abc")
#
# Cell In[27], line 2, in age_validator(age)
#       1 def age_validator(age: int) -> int | None:
# ----> 2     if age <= 0 or age >= 100:
#       3         raise ValueError("Age should be between 0 and 100")
#       4     return age
#
# TypeError: '<=' not supported between instances of 'str' and 'int'

# %%
# Input  24
try:
    input_age = int(input("Please enter age : "))
    validated_age = age_validator(input_age)
    print(f"Valid Age entered : {validated_age}")
except Exception as e:
    print(f"Invalid age entered : {e}")
# Out:
# Valid Age entered : 24

# %%
# Input -3
try:
    input_age = int(input("Please enter age : "))
    validated_age = age_validator(input_age)
    print(f"Valid Age entered : {validated_age}")
except Exception as e:
    print(f"Invalid age entered : {e}")
# Out:
# Invalid age entered : Age should be between 1 and 100

# %%
# Input 101
try:
    input_age = int(input("Please enter age : "))
    validated_age = age_validator(input_age)
    print(f"Valid Age entered : {validated_age}")
except Exception as e:
    print(f"Invalid age entered : {e}")
# Out:
# Invalid age entered : Age should be between 1 and 100

# %%
# Input "abc"
try:
    input_age = int(input("Please enter age : "))
    validated_age = age_validator(input_age)
    print(f"Valid Age entered : {validated_age}")
except Exception as e:
    print(f"Invalid age entered : {e}")
# Out:
# Invalid age entered : invalid literal for int() with base 10: 'abc'

# %% [markdown]
# # Other blocks
# 1. try - Code you want to run
# 2. except - If exception occurs in try block , exception block will be triggered
# 3. else - else block is executed only if try block is successful
# 4. finally - finally block is always executed in the end

# %%
import math

math.sqrt(23)
# Out:
# 4.795831523312719

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
math.sqrt(-1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 math.sqrt(-1)
#
# ValueError: math domain error

# %%
math.sqrt("a")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 math.sqrt("a")
#
# TypeError: must be real number, not str

# %%
def square_root(num: int | float) -> float | None:
    try:
        s = math.sqrt(num)
    except Exception as e:
        print(f"Exception occured : {e}")
    else:
        print(f"Square root of number {num} is {s:.4f}")
        return s
    finally:
        print("Finally block is always executed")

# %%
s1 = square_root(num=16)
# Out:
# Square root of number 16 is 4.0000
# Finally block is always executed

# %%
s1
# Out:
# 4.0

# %%
s2 = square_root(num=12)
# Out:
# Square root of number 12 is 3.4641
# Finally block is always executed

# %%
s2
# Out:
# 3.4641016151377544

# %%
s3 = square_root(num=-15)
# Out:
# Exception occured : math domain error
# Finally block is always executed

# %%
print(s3)
# Out:
# None

# %%
s5 = square_root(num="abc")
# Out:
# Exception occured : must be real number, not str
# Finally block is always executed

# %%
s6 = square_root([1, 2, 3, 4])
# Out:
# Exception occured : must be real number, not list
# Finally block is always executed

# %%
print(s6)
# Out:
# None

# %% [markdown]
# # File Handling
# 1. read a file - 'r'
# 2. write a new file - 'w'
# 4. append new line in a file - 'a'

# %%
# Writing a completely new file
with open("new.txt", "w", encoding="utf-8") as f:
    f.write("My Name is Utkarsh Gaikwad\n")
    f.write("I work as a data scientist\n")

# %%
# Reading the file
with open("new.txt", "r", encoding="utf-8") as f:
    content = f.read()

# Print the content
print(content)
# Out:
# My Name is Utkarsh Gaikwad
# I work as a data scientist

# %%
# Add content in file append mode
with open("new.txt", "a", encoding="utf-8") as f:
    f.write("This line is added via append mode\n")
    f.write("This is another line added\n")

# %%
# Read the file contents
with open("new.txt", "r", encoding="utf-8") as f:
    lines = f.readlines()

# Print all the line
print(lines)
# Out:
# ['My Name is Utkarsh Gaikwad\n', 'I work as a data scientist\n', 'This line is added via append mode\n', 'This is another line added\n']

# %%
type(lines)
# Out:
# list

# %%
for line in lines:
    print(line)
# Out:
# My Name is Utkarsh Gaikwad
#
# I work as a data scientist
#
# This line is added via append mode
#
# This is another line added

# %%
for line in lines:
    print(line.strip())
# Out:
# My Name is Utkarsh Gaikwad
# I work as a data scientist
# This line is added via append mode
# This is another line added

# %%
content = """
a = 23
b = 24
print(a * b)
"""

with open("add.py", "w", encoding="utf-8") as f:
    f.write(content)
