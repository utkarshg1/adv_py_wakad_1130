# %% [markdown]
# # Assignment - Create a class triangle to calculate area / perimeter
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from dataclasses import dataclass
import math


@dataclass
class Triangle:
    a: int | float
    b: int | float
    c: int | float

    def __post_init__(self):
        if (self.a <= 0) or (self.b <= 0) or (self.c <= 0):
            raise ValueError("Sides of triangle cannot be negative or 0")
        if not self.is_triangle():
            raise ValueError("Sum of two sides should be greater than third")

    def is_triangle(self) -> bool:
        return (
            (self.a + self.b > self.c)
            and (self.b + self.c > self.a)
            and (self.a + self.c > self.b)
        )

    def perimeter(self) -> int | float:
        return self.a + self.b + self.c

    def area(self) -> float:
        s = self.perimeter() / 2
        a = math.sqrt(s * (s - self.a) * (s - self.b) * (s - self.c))
        return a

# %%
t1 = Triangle(a=3, b=4, c=5)
print(t1)
# Out:
# Triangle(a=3, b=4, c=5)

# %%
t1.a
# Out:
# 3

# %%
t1.b
# Out:
# 4

# %%
t1.c
# Out:
# 5

# %%
t1.is_triangle()
# Out:
# True

# %%
t1.perimeter()
# Out:
# 12

# %%
t1.area()
# Out:
# 6.0

# %%
t2 = Triangle(a=12.5, b=13.1, c=14)
print(t2)
# Out:
# Triangle(a=12.5, b=13.1, c=14)

# %%
t2.is_triangle()
# Out:
# True

# %%
t2.perimeter()
# Out:
# 39.6

# %%
t2.area()
# Out:
# 74.94547618102112

# %%
t3 = Triangle(a=-12, b=1, c=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t3 = Triangle(a=-12, b=1, c=3)
#
# File <string>:6, in __init__(self, a, b, c)
#
# Cell In[1], line 13, in Triangle.__post_init__(self)
#      11 def __post_init__(self):
#      12     if (self.a <= 0) or (self.b <= 0) or (self.c <= 0):
# ---> 13         raise ValueError("Sides of triangle cannot be negative or 0")
#      14     if not self.is_triangle():
#      15         raise ValueError("Sum of two sides should be greater than third")
#
# ValueError: Sides of triangle cannot be negative or 0

# %%
t4 = Triangle(a=12, b=0, c=13)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 t4 = Triangle(a=12, b=0, c=13)
#
# File <string>:6, in __init__(self, a, b, c)
#
# Cell In[1], line 13, in Triangle.__post_init__(self)
#      11 def __post_init__(self):
#      12     if (self.a <= 0) or (self.b <= 0) or (self.c <= 0):
# ---> 13         raise ValueError("Sides of triangle cannot be negative or 0")
#      14     if not self.is_triangle():
#      15         raise ValueError("Sum of two sides should be greater than third")
#
# ValueError: Sides of triangle cannot be negative or 0

# %%
t5 = Triangle(a=1, b=2, c=4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 t5 = Triangle(a=1, b=2, c=4)
#
# File <string>:6, in __init__(self, a, b, c)
#
# Cell In[1], line 15, in Triangle.__post_init__(self)
#      13     raise ValueError("Sides of triangle cannot be negative or 0")
#      14 if not self.is_triangle():
# ---> 15     raise ValueError("Sum of two sides should be greater than third")
#
# ValueError: Sum of two sides should be greater than third

# %%
trs = [
    Triangle(a=3, b=4, c=5.5),
    Triangle(a=12, b=13, c=14),
    Triangle(a=2, b=3, c=4),
    Triangle(a=12.5, b=13.2, c=15.8),
    Triangle(a=4, b=5, c=6),
]

# %%
for t in trs:
    print(t)
    print(f"Perimeter : {t.perimeter():.2f}")
    print(f"Area : {t.area():.2f}")
    print("\n" + "=" * 50 + "\n")
# Out:
# Triangle(a=3, b=4, c=5.5)
# Perimeter : 12.50
# Area : 5.85
#
# ...
#
# Triangle(a=12, b=13, c=14)
# Perimeter : 39.00
# Area : 72.31
#
# ...
#
# Triangle(a=2, b=3, c=4)
# Perimeter : 9.00
# Area : 2.90
#
# ...
#
# Triangle(a=12.5, b=13.2, c=15.8)
# Perimeter : 41.50
# Area : 79.99
#
# ...
#
# Triangle(a=4, b=5, c=6)
# Perimeter : 15.00
# Area : 9.92
#
# ...
